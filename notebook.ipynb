# %% [markdown]
# # UofT Course Enrollment Tracker
#
# Track the enrollment of most UofT ArtSci courses as they go!!
# As long as it is a course that is offered in the ArtSci timetable,
# you may search for it.
#
# Courses are ALWAYS in the form that is presented in the
# ArtSci timetable. This means that `AAA100H1-F` is valid, but
# `AAA100H1F`, `AAA100H1`, or `AAA100H1 F` is not. Moreover:
#
# `Course designator + course number + H/Y + 1 + '-' + F/S/Y`

# %%
import data_plotter_controller as dpc

cpw = dpc.CoursePlotterWrapper('20229')
cpw.plot_individual('MAT137Y1-Y')  # replace this with the course you want
# to target
